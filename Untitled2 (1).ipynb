# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dftrain = pd.read_csv('/content/train.csv')
dftest =  pd.read_csv('/content/test.csv')

# %%
pd.set_option("display.max_columns",None)

# %%
dftrain.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
dftest.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# **We will convert these into numerical format / Encoding**
# Neighborhood
#
# OverallQual
#
# OverallCond
#
# YearBuilt
#
# Foundation
#
# Electrical
#
# KitchenQual
#
# GarageType
#
# GarageFinish
#
# fence

# %% [markdown]
# **Data integration**

# %%
df = pd.concat([dftrain,dftest])
df.shape
# Out:
# (2919, 81)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2919 entries, 0 to 1458
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             2919 non-null   int64
#  1   MSSubClass     2919 non-null   int64
#  2   MSZoning       2915 non-null   object
#  3   LotFrontage    2433 non-null   float64
#  4   LotArea        2919 non-null   int64
#  5   Street         2919 non-null   object
#  6   Alley          198 non-null    object
#  7   LotShape       2919 non-null   object
#  8   LandContour    2919 non-null   object
#  9   Utilities      2917 non-null   object
#  10  LotConfig      2919 non-null   object
#  11  LandSlope      2919 non-null   object
#  12  Neighborhood   2919 non-null   object
#  13  Condition1     2919 non-null   object
#  14  Condition2     2919 non-null   object
#  15  BldgType       2919 non-null   object
#  16  HouseStyle     2919 non-null   object
# ...

# %%
int_features = df.select_dtypes(include=['int64']).columns
int_features.to_list()
# Out:
# ['Id',
#  'MSSubClass',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold']

# %%
float_features = df.select_dtypes(include=['float64']).columns
float_features.to_list()
# Out:
# ['LotFrontage',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'SalePrice']

# %%
categorical_features = df.select_dtypes(include=['object']).columns
categorical_features.to_list()
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  2919.000000  2919.000000  2433.000000    2919.000000  2919.000000
# mean   1460.000000    57.137718    69.305795   10168.114080     6.089072
# std     842.787043    42.517628    23.344905    7886.996359     1.409947
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     730.500000    20.000000    59.000000    7478.000000     5.000000
# 50%    1460.000000    50.000000    68.000000    9453.000000     6.000000
# 75%    2189.500000    70.000000    80.000000   11570.000000     7.000000
# max    2919.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  2919.000000  2919.000000   2919.000000  2896.000000  2918.000000
# mean      5.564577  1971.312778   1984.264474   102.201312   441.423235
# std       1.113131    30.291442     20.894344   179.334253   455.610826
# ...

# %%
plt.figure(figsize=(19,10))
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df = df.set_index('Id')

# %%
pd.set_option("display.max_rows",None)

# %%
null_percent = (df.isnull().sum() / df.shape[0]) * 100

# %%
null_percent
# Out:
# MSSubClass        0.000000
# MSZoning          0.137033
# LotFrontage      16.649538
# LotArea           0.000000
# Street            0.000000
# Alley            93.216855
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.068517
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# OverallQual       0.000000
# OverallCond       0.000000
# YearBuilt         0.000000
# YearRemodAdd      0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.034258
# Exterior2nd       0.034258
# MasVnrType       60.500171
# MasVnrArea        0.787941
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.774923
# BsmtCond          2.809181
# BsmtExposure      2.809181
# BsmtFinType1      2.706406
# BsmtFinSF1        0.034258
# ...

# %%
miss_value_50 = null_percent[null_percent > 50]
miss_value_50
# Out:
# Alley          93.216855
# MasVnrType     60.500171
# PoolQC         99.657417
# Fence          80.438506
# MiscFeature    96.402878
# dtype: float64

# %%
miss_value_5_20_percent = null_percent[(null_percent>5) & (null_percent<20)]
miss_value_5_20_percent
# Out:
# LotFrontage     16.649538
# GarageType       5.378554
# GarageYrBlt      5.447071
# GarageFinish     5.447071
# GarageQual       5.447071
# GarageCond       5.447071
# dtype: float64

# %%
df['LotFrontage'].value_counts().head()
# Out:
# LotFrontage
# 60.0    276
# 80.0    137
# 70.0    133
# 50.0    117
# 75.0    105
# Name: count, dtype: int64

# %%
sns.heatmap(df[miss_value_5_20_percent.keys()].isnull())
# Out:
# <Axes: ylabel='Id'>

# %%
missing_value_feat =  null_percent[null_percent > 0]
missing_value_feat
# Out:
# MSZoning         0.137033
# LotFrontage     16.649538
# Alley           93.216855
# Utilities        0.068517
# Exterior1st      0.034258
# Exterior2nd      0.034258
# MasVnrType      60.500171
# MasVnrArea       0.787941
# BsmtQual         2.774923
# BsmtCond         2.809181
# BsmtExposure     2.809181
# BsmtFinType1     2.706406
# BsmtFinSF1       0.034258
# BsmtFinType2     2.740665
# BsmtFinSF2       0.034258
# BsmtUnfSF        0.034258
# TotalBsmtSF      0.034258
# Electrical       0.034258
# BsmtFullBath     0.068517
# BsmtHalfBath     0.068517
# KitchenQual      0.034258
# Functional       0.068517
# FireplaceQu     48.646797
# GarageType       5.378554
# GarageYrBlt      5.447071
# GarageFinish     5.447071
# GarageCars       0.034258
# GarageArea       0.034258
# GarageQual       5.447071
# GarageCond       5.447071
# PoolQC          99.657417
# Fence           80.438506
# MiscFeature     96.402878
# SaleType         0.034258
# SalePrice       49.982871
# dtype: float64

# %%
cat_na_feat = missing_value_feat[missing_value_feat.keys().isin(categorical_features) ]
len(cat_na_feat)
# Out:
# 23

# %%
int_na_feat = missing_value_feat[missing_value_feat.keys().isin(int_features) ]
len(int_na_feat)
# Out:
# 0

# %%
float_na_feat = missing_value_feat[missing_value_feat.keys().isin(float_features) ]
len(float_na_feat)
# Out:
# 12

# %%
df['MSZoning'].value_counts()
# Out:
# MSZoning
# RL         2265
# RM          460
# FV          139
# RH           26
# C (all)      25
# Name: count, dtype: int64

# %%
x = sns.countplot(x = df['MSZoning'])
x.bar_label(x.containers[0])
plt.show()

# %%
df_mvi = df.copy()

# %%
mszoningmode = df['MSZoning'].mode()[0]
df_mvi['MSZoning'].replace(np.nan, mszoningmode,inplace = True)
df_mvi['MSZoning'].isnull().sum()
# Out:
# /tmp/ipython-input-2585636652.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_mvi['MSZoning'].replace(np.nan, mszoningmode,inplace = True)
# np.int64(0)

# %%
x = sns.countplot(x = df_mvi['MSZoning'])
x.bar_label(x.containers[0])
plt.show()

# %%
def old_new_countplot(df,df_new,feature):
  plt.subplot(121)
  sns.countplot(x = df[feature])
  plt.subplot(122)
  sns.countplot(x = df_new[feature])

# %%
old_new_countplot(df,df_mvi,'MSZoning')

# %% [markdown]
# handling alley = 93.216855

# %%
df_mvi['Alley'].replace(np.nan,'NA',inplace=True)
df_mvi['Alley'].isnull().sum()
# Out:
# /tmp/ipython-input-909486111.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_mvi['Alley'].replace(np.nan,'NA',inplace=True)
# np.int64(0)

# %%
old_new_countplot(df,df_mvi,'Alley')

# %% [markdown]
# handling lot frontage = 16.6598

# %%
def boxhistplot(df,figsize=(10,7)):
  plt.figure(figsize=figsize)
  plt.subplot(121)
  sns.boxplot(df)
  plt.subplot(122)
  sns.distplot(df)

# %%
boxhistplot(df['LotFrontage'])
# Out:
# /tmp/ipython-input-4226915209.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df)

# %%
lotfrontage_mean = df['LotFrontage'].mean()
df_mvi['LotFrontage'].fillna(lotfrontage_mean,inplace = True)
# Out:
# /tmp/ipython-input-4026767958.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_mvi['LotFrontage'].fillna(lotfrontage_mean,inplace = True)

# %%
df_mvi['LotFrontage'].isnull().sum()
# Out:
# np.int64(0)

# %%
def old_new_boxhistplot(df,df_new,feature):
  plt.figure(figsize=(10,7))

  plt.subplot(221)
  sns.boxplot(x = df[feature])
  plt.title("old data ")
  plt.subplot(222)
  sns.distplot(x = df[feature])
  plt.title("old data ")




  plt.subplot(223)
  sns.boxplot(x = df_new[feature])
  plt.title("new data ")
  plt.subplot(224)
  sns.distplot(x = df_new[feature])
  plt.title("new data ")

# %%
old_new_boxhistplot(df,df_mvi,"LotFrontage")
# Out:
# /tmp/ipython-input-2580292152.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x = df[feature])
# /tmp/ipython-input-2580292152.py:18: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x = df_new[feature])

# %%
df['Utilities'].value_counts()
# Out:
# Utilities
# AllPub    2916
# NoSeWa       1
# Name: count, dtype: int64

# %%
utilities_mode = df['Utilities'].mode()[0]
df_mvi['Utilities'].fillna(utilities_mode,inplace = True)
df_mvi['Utilities'].isnull().sum()
# Out:
# /tmp/ipython-input-4263119769.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_mvi['Utilities'].fillna(utilities_mode,inplace = True)
# np.int64(0)

# %%
Exterior1st_mode = df['Exterior1st'].mode()[0]
df_mvi['Exterior1st'].fillna(Exterior1st_mode,inplace = True)
df_mvi['Exterior1st'].isnull().sum()

Exterior2nd_mode = df['Exterior2nd'].mode()[0]
df_mvi['Exterior2nd'].fillna(Exterior2nd_mode,inplace = True)
df_mvi['Exterior2nd'].isnull().sum()
# Out:
# /tmp/ipython-input-3201693584.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_mvi['Exterior1st'].fillna(Exterior1st_mode,inplace = True)
# /tmp/ipython-input-3201693584.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df_mvi['Exterior1st'].isnull().sum()
# Out:
# np.int64(0)

# %%
sns.heatmap(df[['MasVnrArea', 'MasVnrType']].isnull())
# Out:
# <Axes: ylabel='Id'>

# %%
MasVnrType_mode = df['MasVnrType'].mode()[0]
df_mvi['MasVnrType'].fillna(MasVnrType_mode,inplace = True)
df_mvi['MasVnrType'].isnull().sum()
# Out:
# /tmp/ipython-input-1512261442.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_mvi['MasVnrType'].fillna(MasVnrType_mode,inplace = True)
# np.int64(0)

# %%
boxhistplot(df['MasVnrArea'])
# Out:
# /tmp/ipython-input-4226915209.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df)

# %%
df_mvi['MasVnrArea'].fillna(0 , inplace = True)
df_mvi['MasVnrArea'].isnull().sum()
# Out:
# /tmp/ipython-input-2061603969.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_mvi['MasVnrArea'].fillna(0 , inplace = True)
# np.int64(0)

# %%
cat_bsmt_feat = ['BsmtQual',
 'BsmtCond',
 'BsmtExposure',
 'BsmtFinType1',
 'BsmtFinType2']
num_bsmt_feat = [ 'BsmtFinSF1',
 'BsmtFinSF2',
 'BsmtUnfSF',
 'TotalBsmtSF',
 'BsmtFullBath',
 'BsmtHalfBath']

# %%
sns.heatmap(df[cat_bsmt_feat].isnull())
# Out:
# <Axes: ylabel='Id'>

# %%
for feature in cat_bsmt_feat:
  print(f"value count of {feature} :{df[feature].value_counts()}")
# Out:
# value count of BsmtQual :BsmtQual
# TA    1283
# Gd    1209
# Ex     258
# Fa      88
# Name: count, dtype: int64
# value count of BsmtCond :BsmtCond
# TA    2606
# Gd     122
# Fa     104
# Po       5
# Name: count, dtype: int64
# value count of BsmtExposure :BsmtExposure
# No    1904
# Av     418
# Gd     276
# Mn     239
# Name: count, dtype: int64
# value count of BsmtFinType1 :BsmtFinType1
# Unf    851
# GLQ    849
# ALQ    429
# Rec    288
# BLQ    269
# LwQ    154
# Name: count, dtype: int64
# value count of BsmtFinType2 :BsmtFinType2
# Unf    2493
# Rec     105
# LwQ      87
# BLQ      68
# ALQ      52
# GLQ      34
# Name: count, dtype: int64

# %%
for feature in cat_bsmt_feat:
  df_mvi[feature].fillna('NA',inplace= True)
# Out:
# /tmp/ipython-input-392248065.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_mvi[feature].fillna('NA',inplace= True)

# %%
df_mvi[cat_bsmt_feat].isnull().sum()
# Out:
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# dtype: int64

# %%
sns.heatmap(df[num_bsmt_feat].isnull())
# Out:
# <Axes: ylabel='Id'>

# %%
df_bsmt = df[cat_bsmt_feat + num_bsmt_feat]
df_bsmt[df_bsmt.isnull().any(axis = 1)]
# Out:
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2  BsmtFinSF1  \
# Id
# 18        NaN      NaN          NaN          NaN          NaN         0.0
# 40        NaN      NaN          NaN          NaN          NaN         0.0
# 91        NaN      NaN          NaN          NaN          NaN         0.0
# 103       NaN      NaN          NaN          NaN          NaN         0.0
# 157       NaN      NaN          NaN          NaN          NaN         0.0
# 183       NaN      NaN          NaN          NaN          NaN         0.0
# 260       NaN      NaN          NaN          NaN          NaN         0.0
# 333        Gd       TA           No          GLQ          NaN      1124.0
# 343       NaN      NaN          NaN          NaN          NaN         0.0
# 363       NaN      NaN          NaN          NaN          NaN         0.0
# 372       NaN      NaN          NaN          NaN          NaN         0.0
# 393       NaN      NaN          NaN          NaN          NaN         0.0
# ...

# %%
for feature in num_bsmt_feat:
  df_mvi[feature].fillna(0,inplace= True)
# Out:
# /tmp/ipython-input-681650111.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_mvi[feature].fillna(0,inplace= True)

# %%
df_mvi[num_bsmt_feat].isnull().sum()
# Out:
# BsmtFinSF1      0
# BsmtFinSF2      0
# BsmtUnfSF       0
# TotalBsmtSF     0
# BsmtFullBath    0
# BsmtHalfBath    0
# dtype: int64

# %%
df_ekk = df[["Electrical", "KitchenQual","KitchenAbvGr"] ]
df_ekk[df_ekk.isnull().any(axis = 1)]
# Out:
#      Electrical KitchenQual  KitchenAbvGr
# Id
# 1380        NaN          Gd             1
# 1556      SBrkr         NaN             1

# %%
df_mvi['Electrical'].fillna(df['Electrical'].mode()[0],inplace = True)
df_mvi['Electrical'].isnull().sum()
# Out:
# /tmp/ipython-input-2284684684.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_mvi['Electrical'].fillna(df['Electrical'].mode()[0],inplace = True)
# np.int64(0)

# %%
df_mvi['KitchenQual'].fillna(df['KitchenQual'].mode()[0],inplace = True)
df_mvi['KitchenQual'].isnull().sum()
# Out:
# /tmp/ipython-input-1739959065.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_mvi['KitchenQual'].fillna(df['KitchenQual'].mode()[0],inplace = True)
# np.int64(0)

# %%
df_mvi['Functional'].fillna(df['Functional'].mode()[0],inplace = True)
df_mvi['Functional'].isnull().sum()
# Out:
# /tmp/ipython-input-3574761829.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_mvi['Functional'].fillna(df['Functional'].mode()[0],inplace = True)
# np.int64(0)

# %%
df_mvi['SaleType'].fillna(df['SaleType'].mode()[0],inplace = True)
df_mvi['SaleType'].isnull().sum()
# Out:
# /tmp/ipython-input-2004646326.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_mvi['SaleType'].fillna(df['SaleType'].mode()[0],inplace = True)
# np.int64(0)

# %%
other_cat_feature = [
 'FireplaceQu',
 'PavedDrive',
 'PoolQC',
 'Fence',
 'MiscFeature'
 ]

for feature in other_cat_feature:
  print(f"value count of {feature} :{df[feature].value_counts()}")
# Out:
# value count of FireplaceQu :FireplaceQu
# Gd    744
# TA    592
# Fa     74
# Po     46
# Ex     43
# Name: count, dtype: int64
# value count of PavedDrive :PavedDrive
# Y    2641
# N     216
# P      62
# Name: count, dtype: int64
# value count of PoolQC :PoolQC
# Ex    4
# Gd    4
# Fa    2
# Name: count, dtype: int64
# value count of Fence :Fence
# MnPrv    329
# GdPrv    118
# GdWo     112
# MnWw      12
# Name: count, dtype: int64
# value count of MiscFeature :MiscFeature
# Shed    95
# Gar2     5
# Othr     4
# TenC     1
# Name: count, dtype: int64

# %%
df_mvi['FireplaceQu'].fillna("NA",inplace = True)
df_mvi['FireplaceQu'].isnull().sum()
# Out:
# /tmp/ipython-input-1009370304.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_mvi['FireplaceQu'].fillna("NA",inplace = True)
# np.int64(0)

# %%
df_mvi['PoolQC'].fillna("NA",inplace = True)
df_mvi['PoolQC'].isnull().sum()
# Out:
# /tmp/ipython-input-1895295589.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_mvi['PoolQC'].fillna("NA",inplace = True)
# np.int64(0)

# %%
df_mvi['Fence'].fillna("NA",inplace = True)
df_mvi['Fence'].isnull().sum()
# Out:
# /tmp/ipython-input-183748229.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_mvi['Fence'].fillna("NA",inplace = True)
# np.int64(0)

# %%
df_mvi['MiscFeature'].fillna("NA",inplace = True)
df_mvi['MiscFeature'].isnull().sum()
# Out:
# /tmp/ipython-input-1920502697.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_mvi['MiscFeature'].fillna("NA",inplace = True)
# np.int64(0)

# %%
cat_garage_feat = ['GarageType',
 'GarageFinish',
 'GarageQual',
 'GarageCond'
]
num_garage_feat = [
 'GarageYrBlt',
 'GarageCars',
 'GarageArea']


df_garage = df[cat_garage_feat + num_garage_feat ]
df_garage[df_garage.isnull().any(axis = 1)]
# Out:
#      GarageType GarageFinish GarageQual GarageCond  GarageYrBlt  GarageCars  \
# Id
# 40          NaN          NaN        NaN        NaN          NaN         0.0
# 49          NaN          NaN        NaN        NaN          NaN         0.0
# 79          NaN          NaN        NaN        NaN          NaN         0.0
# 89          NaN          NaN        NaN        NaN          NaN         0.0
# 90          NaN          NaN        NaN        NaN          NaN         0.0
# 100         NaN          NaN        NaN        NaN          NaN         0.0
# 109         NaN          NaN        NaN        NaN          NaN         0.0
# 126         NaN          NaN        NaN        NaN          NaN         0.0
# 128         NaN          NaN        NaN        NaN          NaN         0.0
# 141         NaN          NaN        NaN        NaN          NaN         0.0
# 149         NaN          NaN        NaN        NaN          NaN         0.0
# ...

# %%
for feat in cat_garage_feat:
  df_mvi[feat].fillna("NA",inplace = True)
df_mvi[cat_garage_feat].isnull().sum()
# Out:
# /tmp/ipython-input-3599372308.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_mvi[feat].fillna("NA",inplace = True)
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# dtype: int64

# %%
for feat in num_garage_feat:
  df_mvi[feat].fillna(0,inplace = True)
df_mvi[num_garage_feat].isnull().sum()
# Out:
# /tmp/ipython-input-860263366.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_mvi[feat].fillna(0,inplace = True)
# GarageYrBlt    0
# GarageCars     0
# GarageArea     0
# dtype: int64

# %%
df_mvi.isnull().any(axis = 1).sum()
# Out:
# np.int64(1459)

# %% [markdown]
# **Feature transformation**
#
# converting numerical features into categorical

# %%
feature_for_num_conv = ['MSSubClass' , 'YearBuilt' , 'YearRemodAdd' , 'GarageYrBlt' , 'MoSold' , 'YrSold' ]

for feat in feature_for_num_conv:
  print(df_mvi[feat].dtype)
# Out:
# int64
# int64
# int64
# float64
# int64
# int64

# %%
import calendar
# df_mvi['MoSold'] = df_mvi['MoSold'].apply(lambda x : calendar.month_abbr[x])
df_mvi['MoSold'].unique()
# Out:
# array([ 2,  5,  9, 12, 10,  8, 11,  4,  1,  7,  3,  6])

# %%
for feat in feature_for_num_conv:
  df_mvi[feat] = df_mvi[feat].astype(str)

# %%
ordinal_end_var = [
 'BsmtCond',
 'BsmtExposure',
 'BsmtFinType1',
 'BsmtFinType2',
 'BsmtQual',
 'ExterCond',
 'ExterQual',
 'Functional',
 'GarageCond',
 'GarageFinish',
 'KitchenQual',
 'FireplaceQu',
 'GarageQual',
 'HeatingQC',
 'PoolQC',
 'Utilities',
 'PavedDrive',
 ]
print("Total Number of features to convert ordinal numerical format : ",len(ordinal_end_var))
# Out:
# Total Number of features to convert ordinal numerical format :  17

# %%
from pandas.api.types import CategoricalDtype

# %%
# for feat in ordinal_end_var:
#   df_mvi[feat] = df_mvi[feat].astype(CategoricalDtype(categories = df_mvi[feat].unique(),ordered = True)).cat.codes

# %%
df_mvi['ExterQual'] = df_mvi['ExterQual'].astype(CategoricalDtype(categories =  ["Po", "Fa","TA","Gd","Ex"] ,ordered = True)).cat.codes

# %%
df_mvi['BsmtExposure'] = df_mvi['BsmtExposure'].astype(CategoricalDtype(categories =  ["NA", "No","Mn","Av","Gd"] ,ordered = True)).cat.codes

# %%
df_mvi['BsmtExposure'].value_counts()
# Out:
# BsmtExposure
# 1    1904
# 3     418
# 4     276
# 2     239
# 0      82
# Name: count, dtype: int64

# %%
df_mvi['BsmtExposure'].value_counts()
# Out:
# BsmtExposure
# 1    1904
# 3     418
# 4     276
# 2     239
# 0      82
# Name: count, dtype: int64

# %%
df_mvi['BsmtCond'] = df_mvi['BsmtCond'].astype(CategoricalDtype(categories=['NA', 'Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes
df_mvi['BsmtFinType1'] = df_mvi['BsmtFinType1'].astype(CategoricalDtype(categories=['NA', 'Unf', 'LwQ', 'Rec', 'BLQ','ALQ', 'GLQ'], ordered = True)).cat.codes
df_mvi['BsmtFinType2'] = df_mvi['BsmtFinType2'].astype(CategoricalDtype(categories=['NA', 'Unf', 'LwQ', 'Rec', 'BLQ','ALQ', 'GLQ'], ordered = True)).cat.codes
df_mvi['BsmtQual'] = df_mvi['BsmtQual'].astype(CategoricalDtype(categories=['NA', 'Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes
df_mvi['ExterCond'] = df_mvi['ExterCond'].astype(CategoricalDtype(categories=['Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes
df_mvi['Functional'] = df_mvi['Functional'].astype(CategoricalDtype(categories=['Sal', 'Sev', 'Maj2', 'Maj1', 'Mod','Min2','Min1', 'Typ'], ordered = True)).cat.codes
df_mvi['GarageCond'] = df_mvi['GarageCond'].astype(CategoricalDtype(categories=['NA', 'Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes
df_mvi['GarageQual'] = df_mvi['GarageQual'].astype(CategoricalDtype(categories=['NA', 'Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes
df_mvi['GarageFinish'] = df_mvi['GarageFinish'].astype(CategoricalDtype(categories=['NA', 'Unf', 'RFn', 'Fin'], ordered = True)).cat.codes
df_mvi['HeatingQC'] = df_mvi['HeatingQC'].astype(CategoricalDtype(categories=['Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes
df_mvi['KitchenQual'] = df_mvi['KitchenQual'].astype(CategoricalDtype(categories=['Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes
df_mvi['PavedDrive'] = df_mvi['PavedDrive'].astype(CategoricalDtype(categories=['N', 'P', 'Y'], ordered = True)).cat.codes
df_mvi['PoolQC'] = df_mvi['PoolQC'].astype(CategoricalDtype(categories=['NA', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes
df_mvi['KitchenQual'] = df_mvi['KitchenQual'].astype(CategoricalDtype(categories=['Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes
df_mvi['FireplaceQu'] = df_mvi['FireplaceQu'].astype(CategoricalDtype(categories=['NA', 'Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes
df_mvi['Utilities'] = df_mvi['Utilities'].astype(CategoricalDtype(categories=['ELO', 'NASeWa', 'NASeWr', 'AllPub'], ordered = True)).cat.codes

# %%
df_encode = df_mvi.copy()
object_features = df_encode.select_dtypes(include="object").columns.to_list()

# %%
df_encode = pd.get_dummies(df_encode,columns  = object_features, prefix = object_features,drop_first = True)

# %%
len_train = dftrain.shape[0]

# %%
x_train = df_encode[:len_train].drop('SalePrice',axis = 1)
y_train = df_encode['SalePrice'][:len_train]
x_test = df_encode[len_train:].drop('SalePrice',axis = 1)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
x_train[:3,:]
# Out:
# array([[-0.22335706, -0.20714171,  0.02618016, ..., -0.11785113,
#          0.4676514 , -0.30599503],
#        [ 0.45789401, -0.09188637,  0.02618016, ..., -0.11785113,
#          0.4676514 , -0.30599503],
#        [-0.08710685,  0.07347998,  0.02618016, ..., -0.11785113,
#          0.4676514 , -0.30599503]])

# %%
x_test[:3,:]
# Out:
# array([[ 0.55005111,  0.36392912,  0.        , ..., -0.13469875,
#          0.46021084, -0.29936452],
#        [ 0.59869904,  0.89786065,  0.        , ..., -0.13469875,
#          0.46021084, -0.29936452],
#        [ 0.25816357,  0.80964587,  0.        , ..., -0.13469875,
#          0.46021084, -0.29936452]])

# %%
sc.mean_.shape
# Out:
# (511,)

# %%
sc.n_features_in_
# Out:
# 511

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import SGDRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from xgboost import XGBRegressor
from sklearn.isotonic import IsotonicRegression

# %%
svr = SVR(kernel='rbf')
lr = LinearRegression()
sgd = SGDRegressor()
knn = KNeighborsRegressor()
gpr = GaussianProcessRegressor()
dtr = DecisionTreeRegressor()
gbr = GradientBoostingRegressor(n_estimators = 1000)
rfr = RandomForestRegressor(n_estimators = 1000)
mlp = MLPRegressor()
ir = IsotonicRegression()
xgb = XGBRegressor(bbooster='gbtree')

# %%
models = {
    "a": ["LinearRegression", lr],
    "b": ["SVR", svr],
    "c": ["SGDRegressor", sgd],
    "d": ["KNeighborsRegressor", knn],
    "e": ["GaussianProcessRegressor", gpr],
    "f": ["DecisionTreeRegressor", dtr],
    "g": ["GradientBoostingRegressor", gbr],
    "h": ["RandomForestRegressor", rfr],
    "i": ["MLPRegressor", mlp],
    "j": ["IsotonicRegression", ir],
    "k": ["XGBRegressor", xgb]
}

# %%
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import make_scorer, r2_score

def test_model(model , X_train=x_train, y_train=y_train):
    cv = KFold(n_splits=3, shuffle=True, random_state=45)
    r2 = make_scorer(r2_score)
    r2_val_score = cross_val_score(model, x_train, y_train, cv=cv, scoring=r2)
    score = [r2_val_score.mean()]
    return score

# %%
model_score = []
for model in models:
    print("Training Model: ", models[model][0])  # Accessing the model name (not index 0)
    if models[model][0] == "IsotonicRegression":
    # Skip IsotonicRegression or handle it differently
        print(f"Skipping IsotonicRegression due to input shape issues.")
    else:
        score = test_model(models[model][1], x_train, y_train)

    print("R2 Score: ", score[0])
    model_score.append((models[model][0], score[0]))
# Out:
# Training Model:  LinearRegression
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-468898988.py in <cell line: 0>()
#       6         print(f"Skipping IsotonicRegression due to input shape issues.")
#       7     else:
# ----> 8         score = test_model(models[model][1], x_train, y_train)
#       9
#      10     print("R2 Score: ", score[0])
#
# /tmp/ipython-input-1173023552.py in test_model(model, X_train, y_train)
#       5     cv = KFold(n_splits=3, shuffle=True, random_state=45)
#       6     r2 = make_scorer(r2_score)
# ----> 7     r2_val_score = cross_val_score(model, x_train, y_train, cv=cv, scoring=r2)
#       8     score = [r2_val_score.mean()]
#       9     return score
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# ...

# %% [markdown]
# # Task
# Explain the error in the code, correct it, train and evaluate the models using cross-validation, visualize the model scores, and compare the models to identify the best performing one.

# %% [markdown]
# ## Train and evaluate models
#
# ### Subtask:
# Run the code to train and evaluate the models using cross-validation.

# %% [markdown]
# **Reasoning**:
# The error is caused by passing the entire dataframe to the `test_model` function instead of just the training data. I need to correct the call to `test_model` to use `x_train` and `y_train`.

# %%
model_score = []
for model in models:
    print("Training Model: ", models[model][0])
    if models[model][0] == "IsotonicRegression":
    # Skip IsotonicRegression or handle it differently
        print(f"Skipping IsotonicRegression due to input shape issues.")
        score = [np.nan] # Assign NaN score for skipped model
    else:
        score = test_model(models[model][1], x_train, y_train)

    print("R2 Score: ", score[0])
    model_score.append((models[model][0], score[0]))
# Out:
# Training Model:  LinearRegression
# R2 Score:  0.5138838698908291
# Training Model:  SVR
# R2 Score:  -0.05190432475505443
# Training Model:  SGDRegressor
# R2 Score:  -2816.43375486359
# Training Model:  KNeighborsRegressor
# R2 Score:  0.5388663679049583
# Training Model:  GaussianProcessRegressor
# R2 Score:  -5.1936803415832244
# Training Model:  DecisionTreeRegressor
# R2 Score:  0.6498980338017727
# Training Model:  GradientBoostingRegressor
# R2 Score:  0.8441146607961789
# Training Model:  RandomForestRegressor
# R2 Score:  0.8331546058161007
# Training Model:  MLPRegressor
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...
